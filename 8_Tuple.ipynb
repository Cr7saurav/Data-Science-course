# %% [markdown]
# # Tuples

# %%
 tuple1=(1,2,3,4,5)

# %%
tuple1
# Out:
# (1, 2, 3, 4, 5)

# %%
type(tuple1)
# Out:
# tuple

# %% [markdown]
# # Slicing and Indexing

# %%
tp=(1,2,3,4,5,6,7,8)
print(tp)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
tp[0]
# Out:
# 1

# %%
tp[6]
# Out:
# 7

# %%
tp[0:5]
# Out:
# (1, 2, 3, 4, 5)

# %%
tp[::2]
# Out:
# (1, 3, 5, 7)

# %%
tp[::-1]
# Out:
# (8, 7, 6, 5, 4, 3, 2, 1)

# %%
tp[::-2]
# Out:
# (8, 6, 4, 2)

# %% [markdown]
# # Converting a List to tuple

# %%
my_list=[1,2,3,4,5]
my_list[0]=10

# %%
print(my_list)
# Out:
# [10, 2, 3, 4, 5]

# %%
my_tuple=tuple(my_list)

# %%
print(my_tuple)
# Out:
# (10, 2, 3, 4, 5)

# %% [markdown]
# # Length

# %%
my_tuple
# Out:
# (10, 2, 3, 4, 5)

# %%
len(my_tuple)
# Out:
# 5

# %% [markdown]
# # Presence ND absence of a element in tuple

# %%
10 in my_tuple
# Out:
# True

# %%
20 in my_tuple
# Out:
# False

# %%
20 not in my_tuple
# Out:
# True

# %% [markdown]
# # Finding the index of an element in tuple

# %%
my_tuple
# Out:
# (10, 2, 3, 4, 5)

# %%
my_tuple.index(2)
# Out:
# 1

# %% [markdown]
# # maximum and minimum element in a tuple

# %%
max(my_tuple)
# Out:
# 10

# %%
min(my_tuple)
# Out:
# 2

# %% [markdown]
# # Sum Of All The Element Of Tuple

# %%
sum(my_tuple)
# Out:
# 24

# %%
 my_tuple
# Out:
# (10, 2, 3, 4, 5)

# %%
my_tuple.count(2)
# Out:
# 1

# %% [markdown]
# # Unpacking of Tupe

# %%
ele_1,ele_2,ele_3,ele_4,ele_5=my_tuple

# %%
ele_1
# Out:
# 10

# %%
ele_2
# Out:
# 2

# %% [markdown]
# # Concatination of Tuple

# %%
tuple_1=('H','E','L','L','O')
tuple_2=('T','H','E','R','E')

# %%
tuple_3=tuple_1+tuple_2

# %%
print(tuple_3)
# Out:
# ('H', 'E', 'L', 'L', 'O', 'T', 'H', 'E', 'R', 'E')

# %% [markdown]
# # Sorting elements of tuple

# %%
my_tuple=(20,10,9,8,4,5,3,2,1)

# %%
sorted_elements=sorted(my_tuple)

# %%
print(sorted_elements)
# Out:
# [1, 2, 3, 4, 5, 8, 9, 10, 20]

# %% [markdown]
# # Example:Store Manufacturer Details in tuple

# %%
manufacturer=("Mahindra","India",1988)
print("Manufacturer Details:",manufacturer)
# Out:
# Manufacturer Details: ('Mahindra', 'India', 1988)

# %%
manufacturer[1]
# Out:
# 'India'

# %%
len(manufacturer)
# Out:
# 3

# %%
t=(5,)

# %%
type(t)
# Out:
# tuple
