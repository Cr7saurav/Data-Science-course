# %% [markdown]
# # Conditional Statements

# %%
# IF Statement
age=19
if age>18:
    print("Elegible for Driving License")
# Out:
# Elegible for Driving License

# %%
# IF-ELSE Statement
age=18
if age>18:
    print("Eligible for Voting")
else :
    print("Not Eligible For Voting")
# Out:
# Not Eligible For Voting

# %%
# USER INPUT
a=int(input("Enter A Number"))
a=a/10
print(a)
# Out:
# Enter A Number 1
# 0.1

# %%
a=input("ENTER A String")
# Out:
# ENTER A String Saurav

# %%
# ELIF Statement
marks=int(input("Enter The Marks"))
if marks>80:
     category="Outstanding"
elif marks >=60:
     category="First Division"
elif marks >=40:
     category="Second Divison"
else:
     category="Fail"
print("Student Marks :", marks ,"Category:",category)
# Out:
# Enter The Marks 85
# Student Marks : 85 Category: Outstanding
