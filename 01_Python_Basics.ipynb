# %%
import math

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
'''
Hello
How are you
'''
# Out:
# '\nHello\nHow are you\n'

# %%
# Varible
num1=25
num2=22.5
message="Welcome"

# %%
print(num1)
print(num2)
print(message)
# Out:
# 25
# 22.5
# Welcome

# %%
sqrt_value=math.sqrt(num1)

# %%
print("The Square root of", num1, "is :", sqrt_value)
# Out:
# The Square root of 25 is : 5.0

# %%
import random
random.randint(1,10)
# Out:
# 8

# %%
sum=num1+num2

# %%
print("the sum of",num1 , "and",num2,"is", sum)
# Out:
# the sum of 25 and 22.5 is 47.5

# %% [markdown]
# # Tokens, KEywords, Identifiers

# %%
import keyword
print("python keyword",keyword.kwlist)
# Out:
# python keyword ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Variables and Data Types

# %%
sales_count = 500 #Interger
discount = 23.5 #float
string = "saurav" #string
is_availabe= True #boolean

# %%
type (sales_count)
# Out:
# int

# %%
type (discount)
# Out:
# float

# %%
type (string)
# Out:
# str

# %%
type (is_availabe)
# Out:
# bool
