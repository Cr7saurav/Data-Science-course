# %% [markdown]
# # Operators

# %% [markdown]
# # Arithmetic Operators

# %%
add=100+200
print(add)
# Out:
# 300

# %%
sub=100-200
print(sub)
# Out:
# -100

# %%
mul=100*200
print(mul)
# Out:
# 20000

# %%
divi=100/50
print(divi)
# Out:
# 2.0

# %%
mod=100%12
print(mod)
# Out:
# 4

# %%
floor_divi=24//5
print(floor_divi)
# Out:
# 4

# %%
expo=8**4
print(expo)
# Out:
# 4096

# %%
# case study
item1_price,item1_qty=40,2
item2_price,item2_qty=30,3
item1_total=item1_price * item1_qty
item2_total=item2_price * item2_qty
sub_total =item1_total+item2_total
discount =20
final_discount = sub_total-20
print("subtotal",sub_total)
print("final_discount",final_discount)
# Out:
# subtotal 170
# final_discount 150

# %% [markdown]
# # Comparison Operator

# %%
# Equalto
age=18
print('age == 18:',age==18)
# Out:
# age == 18: True

# %%
# notEqualto
print("age!=18",age != 18)
# Out:
# age!=18 False

# %%
# grater than
print("age grater than 18" , age>18)
# Out:
# age grater than 18 False

# %%
# less than
print("age less than 18" ,age<18)
# Out:
# age less than 18 False

# %%
# >=
print ("age greater than equal to 18", age>=18)
# Out:
# age greater than equal to 18 True

# %%
# <=
print ("age less than equal to 18", age<=18)
# Out:
# age less than equal to 18 True

# %%
# case study
marks= 65
if marks >=75 :
    category = "Distinction"
elif marks >=60 :
    category = "First Class"
elif marks >=40 :
    category = "Pass Class"
else :
    category = "Fail"
print(marks)
print(category)
# Out:
# 65
# First Class

# %% [markdown]
# # LOgical Operators

# %%
# AND 
a=4
b=7
print ( a<b and b>a)
# Out:
# True

# %%
# OR
a=5
b=6
print(a>b or a<b)
# Out:
# True

# %%
# NOT
a=5
print (not(a>7))
# Out:
# True

# %%
# case study
bp= 150
suger = 170
if bp >140 and suger > 160:
    status = "High RisK"
elif bp >140 or suger >160:
    status="Moderate Risk"
else:
    status ="Low Risk"
print ("paitent bp",bp)
print("Paitent Suger",suger)
print("Paitent Status",status)
# Out:
# paitent bp 150
# Paitent Suger 170
# Paitent Status High RisK

# %% [markdown]
# # Assignment Operator

# %%
one_dollar_TO_INR = 91.55

# %%
a=10
a+=5
print (a)
# Out:
# 15

# %%
a-=10
print(a)
# Out:
# 5

# %%
a*=2
print(a)
# Out:
# 2

# %%
a/=5
print (a)
# Out:
# 0.4

# %%
a%=2
print(a)
# Out:
# 0.4

# %%
a=10
a//=7
print (a)
# Out:
# 1

# %%
a**=5
print(a)
# Out:
# 1

# %% [markdown]
# #  Bitwise Operator

# %%
# AND(&)
a=2
b=3
print(a&b)
# Out:
# 2

# %%
# OR(|)
print(a|
    b)
# Out:
# 3

# %%
# XOR(^)
print(a^b)
# Out:
# 1

# %%
# NOT(~)
print(~b)
# Out:
# -4

# %%
# LEFT SHIFT(<<)
a=8
print(a<<2)
# Out:
# 32

# %%
# RIGHT SHIFT(>>)
a=2
print(a>>1
     )
# Out:
# 1
